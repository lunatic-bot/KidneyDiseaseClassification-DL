# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1vlhZ5c7abUKF8xXERIw6m9Te8fW7ow3/view?usp=sharing"
file_id = url.split("/")[-2]
prefix = "https://drive.google.com/uc?export=download&id="
url = prefix + file_id
output = "Kidney-CT-Scan-Images.zip"

gdown.download(url, output)
# Out:
# ---------------------------------------------------------------------------
# FileURLRetrievalError                     Traceback (most recent call last)
# File d:\Coding\DeepLearningProjects\KidneyDiseaseClassification-DL\.venv\Lib\site-packages\gdown\download.py:313, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, resume, format, user_agent, log_messages, progress, skip_download)
#     312 try:
# --> 313     url = get_url_from_gdrive_confirmation(res.text)
#     314 except FileURLRetrievalError as e:
#
# File d:\Coding\DeepLearningProjects\KidneyDiseaseClassification-DL\.venv\Lib\site-packages\gdown\download.py:70, in get_url_from_gdrive_confirmation(contents)
#      69 if not url:
# ---> 70     raise FileURLRetrievalError(
#      71         "Cannot retrieve the public link of the file. "
#      72         "You may need to change the permission to "
#      73         "'Anyone with the link', or have had many accesses. "
# ...
